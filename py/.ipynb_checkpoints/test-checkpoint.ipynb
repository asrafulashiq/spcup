# %%
# %%writefile load.py
from __future__ import  division
import numpy as np
import scipy as sp
%matplotlib inline
from matplotlib import pyplot as plt
# Out:
# Overwriting load.py

# %%
# %load load.py
from __future__ import  division
import numpy as np
import scipy as sp
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
ls
# Out:
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py
# neural.py          test.ipynb         write_mat.pyc

# %%
cd ..
# Out:
# /Users/mac/spcup

# %%
ls
# Out:
# data/         feature_data/ info/         mat/          py/

# %%
cd feature_data/
# Out:
# /Users/mac/spcup/feature_data

# %%
ls
# Out:
# matfile/ pyfile/

# %%
ls A
# Out:
# ls: A: No such file or directory

# %%
import scipy.io

# %%
data_A1 = scipy.io.loadmat('A/A_P1.mat')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-8c40ed88e161> in <module>()
# ----> 1 data_A1 = scipy.io.loadmat('A/A_P1.mat')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in loadmat(file_name, mdict, appendmat, **kwargs)
#     132     """
#     133     variable_names = kwargs.pop('variable_names', None)
# --> 134     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     135     matfile_dict = MR.get_variables(variable_names)
#     136     if mdict is not None:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in mat_reader_factory(file_name, appendmat, **kwargs)
#      55        type detected in `filename`.
#      56     """
# ---> 57     byte_stream = _open_file(file_name, appendmat)
#      58     mjv, mnv = get_matfile_version(byte_stream)
#      59     if mjv == 0:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in _open_file(file_like, appendmat)
#      21     if isinstance(file_like, string_types):
#      22         try:
# ---> 23             return open(file_like, 'rb')
#      24         except IOError as e:
#      25             if appendmat and not file_like.endswith('.mat'):
#
# IOError: [Errno 2] No such file or directory: 'A/A_P1.mat'

# %%
data_A1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-161bb91c186b> in <module>()
# ----> 1 data_A1
#
# NameError: name 'data_A1' is not defined

# %%
len(data_A1['diff_x'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d42dea5ead3b> in <module>()
# ----> 1 len(data_A1['diff_x'][0])
#
# NameError: name 'data_A1' is not defined

# %%
ls
# Out:
# matfile/ pyfile/

# %%
mkdir tmp

# %%
ls
# Out:
# matfile/ pyfile/  tmp/

# %%
a=[1,2,3]
b = [1,4,9]
c = [1,8,27]

# %%
zip(a,b,c)
# Out:
# [(1, 1, 1), (2, 4, 8), (3, 9, 27)]

# %%
chr(3+ord('A'))
# Out:
# 'D'

# %%
ls
# Out:
# A/   C/   E/   G/   tmp/
# B/   D/   F/   H/

# %%
cd ..
# Out:
# /Users/mac/spcup

# %%
ls
# Out:
# data/         mat/
# feature_data/ py/
# info/

# %%
cd py
# Out:
# /Users/mac/spcup/py

# %%
ls
# Out:
# load.py       test.ipynb
# pbrain.py     write_npy.py

# %%
import re
f_name = []
for i in data_A1:
    if not re.match(r'__*',i) and i!='F' :
        if not re.match(r'global*',i):
            f_name.append(i)

# %%
a = '__vv__'

# %%
import re

# %%
re.match('__*',a)

# %%
data_A1
# Out:
# {'F': array([[ 59.93061044,  60.53041577,  61.21050485, ...,  60.03051455,
#           60.02526403,  60.02813263]]),
#  '__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file, Platform: MACI64, Created on:
#            1.81083246e-05,   5.69813809e-05,   4.80554605e-05,
#            2.09809198e-05,   3.31986140e-05,   1.07790600e-05,
#            1.04137275e-05,   8.59673368e-06,   1.52175473e-05,
#            8.08867822e-06,   8.44769382e-06,   3.12281306e-05,
#            8.48508172e-06,   6.50619223e-06,   1.00122244e-05,
#            4.47452785e-06,   1.03841235e-05,   1.04503998e-05,
#            1.85391995e-05,   1.28563488e-05,   2.70413472e-05,
#            1.87237718e-04,   1.23021090e-05]]),
#  'wavcoef_n': array([[  2.19931101e+01,   2.19603618e+01,   2.19640971e+01, ...,
#            2.19492000e+01,   2.19554122e+01,   2.19671076e+01],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         ...,
#         [ -6.77524553e-05,  -4.78386755e-06,  -2.12099332e-05, ...,
#            7.90665302e-05,  -9.64473913e-05,   6.53114314e-05],
#         [ -6.47930008e-05,  -1.61798264e-05,   4.66960888e-05, ...,
#            4.57511754e-05,  -6.46980661e-05,   4.36272177e-05],
#         [ -5.91117313e-05,  -3.79559426e-05,  -2.58618055e-05, ...,
#            2.23990571e-05,   2.99465113e-05,  -2.69882103e-05]])}

# %%
zip([1,2,3],[4])
# Out:
# [(1, 4)]

# %%
f_name
# Out:
# ['skew_x', 'wavcoef_n', 'diff_x', 'kurt_x', 'mean_x', 'var_x']

# %%
x = [ data_A1[i][0] for i in f_name ]

# %%
len(x)
# Out:
# 6

# %%
a=zip(*[ data_A1[i][0] for i in f_name ])

# %%
len(a)
# Out:
# 281

# %%
# %load write_npy.py
##
#   load .mat files and write the contens to a 
#   .npz file.
#   the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np

inputs = []
targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                feature_name.append(i)

    inputs.extend(zip( 
            *[ data[i][0] for i in feature_name ]
         ))

    targets.extend([0 for i in xrange(len(inputs))])

# %%
file = '../feature_data/matfile/A/A_P1.mat'

# %%
data = loadMat(file)

# %%
load_local_features(data)

# %%
len(inputs)
# Out:
# 281

# %%
inputs[0]
# Out:
# (3.486627213923958,
#  21.993110076534109,
#  2.0812836486775907,
#  14.46856641323966,
#  60.108116984777837,
#  0.15589071340541458)

# %%
len(inputs)
# Out:
# 281

# %%
len(targets)
# Out:
# 281

# %%
a=[1 2 3]
# Out:
#   File "<ipython-input-119-7f0dbc2253fc>", line 1
#     a=[1 2 3]
#          ^
# SyntaxError: invalid syntax

# %%
'{0},{0}'.format('qwe',4)
# Out:
# 'qwe,qwe'

# %%
file
# Out:
# '../feature_data/matfile/A/A_P1.mat'

# %%
import os

# %%
os.path.exists(file)
# Out:
# True

# %%
# %load write_npy.py
##
#   load .mat files and write the contens to a 
#   .npz file.
#   the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                feature_name.append(i)
    inputs.extend(
        zip( *[ data[i][0] for i in feature_name ])
    )

    targets.extend( [0 for i in xrange(len(inputs))] )


def main():
    grids = ['A','B','C','D','E','F','G','H'];

    for grid in grids:
        for i in xrange(1,12):
            filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            .format(grid,i)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename)
                )

if __name__ == '__main__':
    main()

# %%
main()

# %%
len(inputs)
# Out:
# 69126

# %%
len(targets)
# Out:
# 8537061

# %%
ord('A')-''
# Out:
# 65

# %%
# %load write_npy.py
##
#   load .mat files and write the contens to a 
#   .npz file.
#   the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data,target_value):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                feature_name.append(i)
                #print '#1'
    input  = zip( *[ data[i][0] for i in feature_name ])
    #print input

    target =  [target_value for i in xrange(len(input))] 

    inputs.extend(input)
    targets.extend(target)
    


def main():
    grids = ['A','B','C','D','E','F','G','H'];

    for grid in grids:
        for i in xrange(1,12):
            filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            .format(grid,i)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename), ord(grid)-ord('A')
                )

if __name__ == '__main__':
    main()

# %%
main()

# %%
filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            .format('A',1)

# %%
data = loadMat(filename)

# %%
inputs
# Out:
# [(3.486627213923958,
#   21.993110076534109,
#   2.0812836486775907,
#   14.46856641323966,
#   60.108116984777837,
#   0.15589071340541458),
#  (0.22104385500985299,
#   21.96036177677469,
#   0.0067130061421138976,
#   2.4416242504918921,
#   60.018614471211471,
#   1.9842047264507494e-05),
#  (0.23794538327852713,
#   21.9640971226675,
#   0.006151503498671218,
#   2.8392031337408548,
#   60.028823332401274,
#   7.880600393474975e-06),
#  (-0.26886402766499323,
#   21.960659134996586,
#   0.0067454323879800882,
#   2.3260618433854079,
#   60.019427164037822,
#   1.9558798742116676e-05),
#  (-0.15994364766022284,
#   21.955169702984239,
#   0.0062703093515210639,
#   1.9957717167343092,
#   60.0044243099426,
#   1.9162979597266972e-05),
#  (0.34160455048360544,
#   21.952649107635715,
#   0.0072048753792799403,
#   2.1914498993980316,
#   59.997535414304245,
#   0.0067736972039966759,
#   2.6544930300247982,
#   60.002472490500587,
#   3.8473239099122721e-06),
#  (-0.31201131996994458,
#   21.955786357096997,
#   0.0077682774480223316,
#   1.9420293036315097,
#   60.006109652189295,
#   8.0268054106374184e-06),
#  (-0.027576803298312625,
#   21.954296534110703,
#   0.0072605890245469595,
#   2.1674442760080215,
#   60.002037901807704,
#   2.1111261723261009e-05),
#  (-0.084455766869381776,
#   21.950622265529333,
#   0.0080726812487696975,
#   2.7622311613438977,
#   59.99199596754039,
#   9.7352784724445505e-06),
#  (-0.26454747695214237,
#   21.947766566657506,
#   0.007169267947681135,
#   2.1063910930420664,
#   59.984191219541415,
#   1.1536273338629476e-05),
#  (-0.41467771694889688,
#   21.945265741487191,
#   0.0071431938744126455,
#   2.2785031593656826,
#   59.977356356651498,
#   6.1943284459472597e-06),
#  (0.01630566941478714,
#   21.944888019302887,
#   0.0082977327807256529,
#   1.9892290697901778,
#   59.976324025654982,
#   8.0353308550703425e-06),
#  (0.66615172402869238,
#   21.945655175370099,
#   0.0069867097078102347,
#   2.9604184384285679,
#   59.978420696224688,
#   8.5940868201681314e-06),
#  (-0.20315059959793597,
#   21.949781054620129,
#   0.0073329292679602531,
#   2.3036943980989899,
#   59.989696901898334,
#   1.645148946836513e-05),
#  (0.13848578518254773,
#   21.948379156599749,
#   0.0072931123874582227,
#   2.8713661042868863,
#   59.985865454235118,
#   1.7709874505423784e-05),
#  (-0.06097596006572939,
#   21.944061690213427,
#   0.0067629576673340352,
#   2.4346547399222089,
#   59.974065632667191,
#   2.6746428416612408e-05),
#  (0.59443292218559685,
#   21.942045817513041,
#   0.0061759187102126134,
#   2.3736171750516677,
#   59.968556165762308,
#   1.9724214477907869e-05),
#  (-0.27097431384902571,
#   21.950683756171031,
#   0.0079517241142426087,
#   2.0964432448133441,
#   59.992164024112292,
#   4.8707472243169889e-05),
#  (-0.38986268122973167,
#   21.952989775925339,
#   0.0076455900762013584,
#   3.1452388324215019,
#   59.998466475410837,
#   1.7367346870178598e-05),
#  (0.16196888459738176,
#   21.946811118008384,
#   0.0068457672002466552,
#   2.0081049385296117,
#   59.981579937236432,
#   3.9425596244947989e-05),
#  (0.026869671505968855,
#   21.94443895115937,
#   0.0069942846301245254,
#   2.2831239379163346,
#   59.975096703079394,
#   1.5704483130370007e-05),
#  (0.018504927833722377,
#   21.94619564531618,
#   0.0061384668589354874,
#   2.2015089745538532,
#   59.979897823862977,
#   5.8579856112681241e-06),
#  (-0.36888124572122327,
#   21.947476563474545,
#   0.0069013944412503747,
#   3.2426743667778379,
#   59.983398628353228,
#   5.9844767210947701e-06),
#  ...]

# %%
len(inputs)
# Out:
# 46365

# %%
len(targets)
# Out:
# 46365

# %%
np.savez_compressed?

# %%
ls
# Out:
# features.npz  test.ipynb
# load.py       write_npy.py
# pbrain.py

# %%
cd ..
# Out:
# /Users/mac/spcup

# %%
ls
# Out:
# data/         mat/
# feature_data/ py/
# info/

# %%
ls feature_data/pyfile
# Out:
# features.npz

# %%
ls
# Out:
# data/         mat/
# feature_data/ py/
# info/

# %%
file = 'feature_data/pyfile/features.mat'

# %%
dat = np.load(file)

# %%
dat

# %%
dat['inputs']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-197-3e2d077acf64> in <module>()
# ----> 1 dat['inputs']
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/numpy/lib/npyio.pyc in __getitem__(self, key)
#     207                 return self.zip.read(key)
#     208         else:
# --> 209             raise KeyError("%s is not a file in the archive" % key)
#     210
#     211     def __iter__(self):
#
# KeyError: 'inputs is not a file in the archive'

# %%
len(dat['arr_1'])
# Out:
# 23042

# %%
len(inputs)
# Out:
# 46365

# %%
inputs[:3]
# Out:
# [(3.486627213923958,
#   21.993110076534109,
#   2.0812836486775907,
#   14.46856641323966,
#   60.108116984777837,
#   0.15589071340541458),
#  (0.22104385500985299,
#   21.96036177677469,
#   0.0067130061421138976,
#   2.4416242504918921,
#   60.018614471211471,
#   1.9842047264507494e-05),
#  (0.23794538327852713,
#   21.9640971226675,
#   0.006151503498671218,
#   2.8392031337408548,
#   60.028823332401274,
#   7.880600393474975e-06)]

# %%
dat['arr_1'][:3]
# Out:
# array([0, 0, 0])

# %%
scipy.io.savemat?

# %%
file = 'feature_data/pyfile/features.mat'

# %%
dat = scipy.io.loadmat(file)

# %%
dat['inputs']
# Out:
# array([[  3.48662721e+00,   2.19931101e+01,   2.08128365e+00,
#           1.44685664e+01,   6.01081170e+01,   1.55890713e-01],
#        [  2.21043855e-01,   2.19603618e+01,   6.71300614e-03,
#           2.44162425e+00,   6.00186145e+01,   1.98420473e-05],
#        [  2.37945383e-01,   2.19640971e+01,   6.15150350e-03,
#           2.83920313e+00,   6.00288233e+01,   7.88060039e-06],
#        ...,
#        [  1.13599637e-01,   2.19492000e+01,   7.33557297e-03,
#           2.21293654e+00,   5.99881089e+01,   2.70413472e-05],
#        [  2.14334856e-01,   2.19554122e+01,   8.43503597e-03,
#           1.89998084e+00,   6.00050870e+01,   1.87237718e-04],
#        [  2.89585366e-02,   2.19671076e+01,   5.71196655e-03,
#           2.10784736e+00,   6.00370510e+01,   1.23021090e-05]])

# %%
# %load neural.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-0857544b64a3> in <module>()
# ----> 1 get_ipython().magic(u'load neural.py')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/magics/code.pyc in load(self, arg_s)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/magics/code.pyc in load(self, arg_s)
#     312         search_ns = 'n' in opts
#     313
# --> 314         contents = self.shell.find_user_code(args, search_ns=search_ns)
#     315
#     316         if 's' in opts:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3365         except Exception:
#    3366             raise ValueError(("'%s' was not found in history, as a file, url, "
# -> 3367                                 "nor in the user namespace.") % target)
#    3368
#    3369         if isinstance(codeobj, string_types):
#
# ValueError: 'neural.py' was not found in history, as a file, url, nor in the user namespace.

# %%
ls
# Out:
# data/         mat/
# feature_data/ py/
# info/

# %%
cd py
# Out:
# /Users/mac/spcup/py

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
import pybrain

def load_data():
    """
    load dataset for classification
    """
    import sys
    import os.path

    filename = sys.argv[1]

    assert os.path.exists(filename)==True

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
import pybrain

def load_data(filename):
    """
    load dataset for classification
    """
    assert os.path.exists(filename)==True

# %%
filename = '../feature_data/pyfile/features.mat'

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
import scipy.io
from matplotlib import pyplot as plt
import pybrain

def load_data(filename):
    """
    load dataset for classification
    """
    assert os.path.exists(filename)==True
    dat = scipy.io.loadmat(filename)
    inputs = dat['inputs'][0]
    targets = dat['targets'][0]

    assert len(inputs)==len(targets)

# %%
load_data(filename)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-220-cba28fee7f48> in <module>()
# ----> 1 load_data(filename)
#
# <ipython-input-218-43dd314caed1> in load_data(filename)
#      21     targets = dat['targets'][0]
#      22
# ---> 23     assert len(inputs)==len(targets)
#      24
#
# AssertionError:

# %%
dat = scipy.io.loadmat(filename)

# %%
dat['inputs']
# Out:
# array([[  3.48662721e+00,   2.19931101e+01,   2.08128365e+00,
#           1.44685664e+01,   6.01081170e+01,   1.55890713e-01],
#        [  2.21043855e-01,   2.19603618e+01,   6.71300614e-03,
#           2.44162425e+00,   6.00186145e+01,   1.98420473e-05],
#        [  2.37945383e-01,   2.19640971e+01,   6.15150350e-03,
#           2.83920313e+00,   6.00288233e+01,   7.88060039e-06],
#        ...,
#        [  1.13599637e-01,   2.19492000e+01,   7.33557297e-03,
#           2.21293654e+00,   5.99881089e+01,   2.70413472e-05],
#        [  2.14334856e-01,   2.19554122e+01,   8.43503597e-03,
#           1.89998084e+00,   6.00050870e+01,   1.87237718e-04],
#        [  2.89585366e-02,   2.19671076e+01,   5.71196655e-03,
#           2.10784736e+00,   6.00370510e+01,   1.23021090e-05]])

# %%
# %load write_mat.py
##
#   load .mat files and write the contens to a 
#   .mat file.
#    the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def init():
    inputs = []
    targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data,target_value):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                feature_name.append(i)
    input  = zip( *[ data[i][0] for i in feature_name ])

    target =  [target_value for i in xrange(len(input))] 

    inputs.extend(input)
    targets.extend(target)

def write_to_file(filename):
    '''
        write inputs and targets to a filename .mat file
     '''
    #np.savez(filename,inputs,targets)
    scipy.io.savemat(filename, mdict = {'inputs':inputs,'targets':targets} )



def main():
    grids = ['A','B','C','D','E','F','G','H'];
    init()

    for grid in grids:
        for i in xrange(1,12):
            filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            .format(grid,i)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename), ord(grid)-ord('A')
                )
    file_to_save = '../feature_data/pyfile/features.mat'
    write_to_file(file_to_save)

if __name__ == '__main__':
    main()

# %%
len(inputs)
# Out:
# 23042

# %%
inputs[:4]
# Out:
# [(3.486627213923958,
#   21.993110076534109,
#   2.0812836486775907,
#   14.46856641323966,
#   60.108116984777837,
#   0.15589071340541458),
#  (0.22104385500985299,
#   21.96036177677469,
#   0.0067130061421138976,
#   2.4416242504918921,
#   60.018614471211471,
#   1.9842047264507494e-05),
#  (0.23794538327852713,
#   21.9640971226675,
#   0.006151503498671218,
#   2.8392031337408548,
#   60.028823332401274,
#   7.880600393474975e-06),
#  (-0.26886402766499323,
#   21.960659134996586,
#   0.0067454323879800882,
#   2.3260618433854079,
#   60.019427164037822,
#   1.9558798742116676e-05)]

# %%
i = dat['inputs']

# %%
i[0]
# Out:
# array([  3.48662721,  21.99311008,   2.08128365,  14.46856641,
#         60.10811698,   0.15589071])

# %%
import os.path

# %%
os.path.exists(filename)
# Out:
# True

# %%
j = dat['targets'][0]

# %%
j
# Out:
# array([0, 0, 0, ..., 7, 7, 7])

# %%
len(j)
# Out:
# 23042

# %%
# %load write_mat.py
##
#   load .mat files and write the contens to a 
#   .mat file.
#    the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def init():
    inputs = []
    targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data,target_value):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                feature_name.append(i)
    input  = zip( *[ data[i][0] for i in feature_name ])

    target =  [target_value for i in xrange(len(input))] 

    inputs.extend(input)
    targets.extend(target)

def write_to_file(filename):
    '''
        write inputs and targets to a filename .mat file
     '''
    #np.savez(filename,inputs,targets)
    scipy.io.savemat(filename, mdict = {'inputs':inputs,'targets':targets} )



def main():
    grids = ['A','B','C','D','E','F','G','H'];
    init()

    for grid in grids:
        for i in xrange(1,12):
            filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            .format(grid,i)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename), ord(grid)-ord('A')
                )
    file_to_save = '../feature_data/pyfile/features.mat'
    write_to_file(file_to_save)

if __name__ == '__main__':
    main()

# %%
main()

# %%
len(inputs)
# Out:
# 46084

# %%
len(targets)
# Out:
# 46084

# %%
# %load
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-253-826a0e90d2a6> in <module>()
#      39
#      40 if __name__ == '__main__':
# ---> 41     main()
#
# <ipython-input-253-826a0e90d2a6> in main()
#      35     filename = sys.argv[1]
#      36
# ---> 37     load_data(filename)
#      38
#      39
#
# <ipython-input-253-826a0e90d2a6> in load_data(filename)
#      19     load dataset for classification
#      20     """
# ---> 21     assert os.path.exists(filename)==True
#      22     dat = scipy.io.loadmat(filename)
#      23     inputs = dat['inputs']
#
# AssertionError:

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
import scipy.io
from matplotlib import pyplot as plt
import pybrain

import sys
import os.path

def load_data(filename):
    """
    load dataset for classification
    """
    assert os.path.exists(filename)==True
    dat = scipy.io.loadmat(filename)
    inputs = dat['inputs']

    print len(inputs)

    targets = dat['targets']
    print len(targets)

    #assert len(inputs)==len(targets)

def main():
    

    #filename = sys.argv[1]
    filename = '../feature_data/pyfile/features.mat'
    load_data(filename)


if __name__ == '__main__':
    main()
# Out:
# 46084
# 1

# %%
dat
# Out:
# {'__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Thu Oct 15 12:29:49 2015',
#  '__version__': '1.0',
#  'inputs': array([[  3.48662721e+00,   2.19931101e+01,   2.08128365e+00,
#            1.44685664e+01,   6.01081170e+01,   1.55890713e-01],
#         [  2.21043855e-01,   2.19603618e+01,   6.71300614e-03,
#            2.44162425e+00,   6.00186145e+01,   1.98420473e-05],
#         [  2.37945383e-01,   2.19640971e+01,   6.15150350e-03,
#            2.83920313e+00,   6.00288233e+01,   7.88060039e-06],
#         ...,
#         [  1.13599637e-01,   2.19492000e+01,   7.33557297e-03,
#            2.21293654e+00,   5.99881089e+01,   2.70413472e-05],
#         [  2.14334856e-01,   2.19554122e+01,   8.43503597e-03,
#            1.89998084e+00,   6.00050870e+01,   1.87237718e-04],
#         [  2.89585366e-02,   2.19671076e+01,   5.71196655e-03,
#            2.10784736e+00,   6.00370510e+01,   1.23021090e-05]]),
#  'targets': array([[0, 0, 0, ..., 7, 7, 7]])}

# %%
null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-257-674441960ca1> in <module>()
# ----> 1 null
#
# NameError: name 'null' is not defined

# %%
None

# %%
global x

# %%
# %run neural.py

# %%
alldata

# %%
alldata?

# %%
type(alldata)
# Out:
# NoneType

# %%
i = alldata.getField('inputs')
len(i)
# Out:
# 46084

# %%
len(alldata['targets'])
# Out:
# 46084

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
import scipy.io
from matplotlib import pyplot as plt
import pybrain

import sys
import os.path

from pybrain.datasets import ClassificationDataSet
from pybrain.utilities import percentError
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules import SoftmaxLayer

from pylab import ion, ioff, figure, draw, contourf, clf, show, hold, plot
from scipy import diag, arange, meshgrid, where
from numpy.random import multivariate_normal




def load_data(filename):
    """
    load dataset for classification
    """
    assert os.path.exists(filename)==True
    dat = scipy.io.loadmat(filename)
    inputs = dat['inputs']
    #print len(inputs)
    targets = dat['targets'][0]
    #print len(targets)
    assert len(inputs)==len(targets)

    global alldata
    global indim 
    global outdim

    indim = len(inputs[0])
    outdim = 1
    #print indim
    alldata = ClassificationDataSet(indim, 1, nb_classes = 8)
    alldata.setField('inputs',inputs)
    alldata.setField('targets',targets)

    assert len(alldata['inputs'])==len(alldata['targets'])
    print type(alldata)



 
#filename = sys.argv[1]
filename = '../feature_data/pyfile/features.mat'
load_data(filename)


## divide training and testing data
proportion  = 0.25
tstdata_temp, trndata_temp = alldata.splitWithProportion(proportion)

## this is for some bugs in pybrain
tstdata = ClassificationDataSet(indim, outdim, nb_classes=8)
for n in xrange(0, tstdata_temp.getLength()):
    tstdata.addSample(
        tstdata_temp.getSample(n)[0], tstdata_temp.getSample(n)[1])

trndata = ClassificationDataSet(indim, outdim, nb_classes=8)
for n in xrange(0, trndata_temp.getLength()):
    trndata.addSample(
        trndata_temp.getSample(n)[0], trndata_temp.getSample(n)[1])

print type(trndata)
trndata._convertToOneOfMany()
tstdata._convertToOneOfMany()

print "Number of training patterns: ", len(trndata)
print "Input and output dimensions: ", trndata.indim, trndata.outdim
print "First sample (input, target, class):"
#print trndata['input'][0], trndata['target'][0], trndata['class'][0]





#if __name__ == '__main__':
 #   main()
# Out:
# <class 'pybrain.datasets.classification.ClassificationDataSet'>
# <class 'pybrain.datasets.classification.ClassificationDataSet'>
# Number of training patterns:  0
# Input and output dimensions:  6 8
# First sample (input, target, class):

# %%
len(trndata['input'])
# Out:
# 0

# %%
trndata_temp['input']
# Out:
# array([], shape=(0, 6), dtype=float64)

# %%
tstdata_temp, trndata_temp = alldata.splitWithProportion(proportion)

# %%
tstdata_temp

# %%
alldata

# %%
inp = alldata['inputs']

# %%
# %load neural.py
##
#   neural network in python
#   made usig pybrain module
#

# standart module
import numpy as np
import scipy as sp
import scipy.io
from matplotlib import pyplot as plt
import pybrain

import sys
import os.path

from pybrain.datasets import ClassificationDataSet
from pybrain.utilities import percentError
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules import SoftmaxLayer

from pylab import ion, ioff, figure, draw, contourf, clf, show, hold, plot
from scipy import diag, arange, meshgrid, where
from numpy.random import multivariate_normal




def load_data(filename):
    """
    load dataset for classification
    """
    assert os.path.exists(filename)==True
    dat = scipy.io.loadmat(filename)
    inputs = dat['inputs']
    print len(inputs)
    targets = dat['targets'][0]
    print len(targets)
    assert len(inputs)==len(targets)

    global alldata
    global indim 
    global outdim

    indim = len(inputs[0])
    outdim = 1
    print indim
    alldata = ClassificationDataSet(indim, outdim, nb_classes = 8)
    alldata.setField('input',inputs)
    alldata.setField('target',targets)

    assert len(alldata['input'])==len(alldata['target'])
    print type(alldata)



 
#filename = sys.argv[1]
filename = '../feature_data/pyfile/features.mat'
load_data(filename)


## divide training and testing data
proportion  = 0.25
tstdata_temp, trndata_temp = alldata.splitWithProportion(proportion)

## this is for some bugs in pybrain
tstdata = ClassificationDataSet(indim, outdim, nb_classes=8)
for n in xrange(0, tstdata_temp.getLength()):
    tstdata.addSample(
        tstdata_temp.getSample(n)[0], tstdata_temp.getSample(n)[1])

trndata = ClassificationDataSet(indim, outdim, nb_classes=8)
for n in xrange(0, trndata_temp.getLength()):
    trndata.addSample(
        trndata_temp.getSample(n)[0], trndata_temp.getSample(n)[1])

print type(trndata)
trndata._convertToOneOfMany()
tstdata._convertToOneOfMany()

print "Number of training patterns: ", len(trndata)
print "Input and output dimensions: ", trndata.indim, trndata.outdim
print "First sample (input, target, class):"
#print trndata['input'][0], trndata['target'][0], trndata['class'][0]





#if __name__ == '__main__':
 #   main()
# Out:
# 46084
# 46084
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-288-3cee3734ab7f> in <module>()
#      59 #filename = sys.argv[1]
#      60 filename = '../feature_data/pyfile/features.mat'
# ---> 61 load_data(filename)
#      62
#      63
#
# <ipython-input-288-3cee3734ab7f> in load_data(filename)
#      49     alldata = ClassificationDataSet(indim, outdim, nb_classes = 8)
#      50     alldata.setField('input',inputs)
# ---> 51     alldata.setField('target',targets)
#      52
#      53     assert len(alldata['input'])==len(alldata['target'])
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyBrain-0.3.3-py2.7.egg/pybrain/datasets/supervised.pyc in setField(self, label, arr, **kwargs)
#      60             self.indim = self.getDimension('input')
#      61         elif label == 'target':
# ---> 62             self.outdim = self.getDimension('target')
#      63
#      64     def _provideSequences(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/PyBrain-0.3.3-py2.7.egg/pybrain/datasets/dataset.pyc in getDimension(self, label)
#     146         `label`."""
#     147         try:
# --> 148             dim = self.data[label].shape[1]
#     149         except KeyError:
#     150             raise KeyError('dataset field %s not found.' % label)
#
# IndexError: tuple index out of range

# %%
alldata['input'][0]
# Out:
# array([  3.48662721,  21.99311008,   2.08128365,  14.46856641,
#         60.10811698,   0.15589071])

# %%
ls
# Out:
# load.py            neural.pyc         test.ipynb         write_mat.py
# neural.py          pbrain.py          test_write_mat.py  write_mat.pyc

# %%
ls
# Out:
# load.py            neural.pyc         test.ipynb         write_mat.py
# neural.py          pbrain.py          test_write_mat.py  write_mat.pyc

# %%
import scipy.io

# %%
sp
# Out:
# <module 'scipy' from '/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/__init__.pyc'>

# %%
allf = scipy.io.loadmat('../mat/saperate_data.mat')

# %%
target = allf['responsevar']

# %%
# %%writefile index.py
## get last index of every grid
ind = np.zeros(8)
current = 0
for i in xrange(1,8):
    while True:
        if target[current][0]>i:
            ind[i-1] = current - 1
            break
        current += 1            
    
ind[7] = len(target)-1
ind = [int(i) for i in ind]
# Out:
# Overwriting index.py

# %%
# %load index.py
## get last index of every grid
ind = np.zeros(8)
current = 0
for i in xrange(1,8):
    while True:
        if target[current][0]>i:
            ind[i-1] = current - 1
            break
        current += 1            
    
ind[7] = len(target)-1
ind = [int(i) for i in ind]

# %%
allf['diff_x'][0]
# Out:
# array([ 0.00540436,  0.00587311,  0.00639082, ...,  0.00113175,
#         0.0011955 ,  0.00118974])

# %%
plt.plot(allf['diff_x'][0][0:500])
plt.hold()
plt.plot(allf['diff_x'][0][ind[0]:ind[0]+500],'g')
plt.hold()
plt.plot(allf['diff_x'][0][ind[1]:ind[1]+500],'y')
#plt.hold()

# %%
# %load load.py
from __future__ import  division
import numpy as np
import scipy as sp
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
import scipy.io

# %%
file = '../mat/me/matlab.mat'

# %%
dat = scipy.io.loadmat(file);

# %%
len(dat['F'][0])
# Out:
# 1080

# %%
plt.plot(dat['F'][0])

# %%
alld = scipy.io.loadmat('../feature_data/matfile/A/A_P1.mat')
plt.plot(alld['F'][0])

# %%
alld = scipy.io.loadmat('../feature_data/matfile/A/A_P7.mat')
plt.plot(alld['F'][0])

# %%
alld = scipy.io.loadmat('../feature_data/matfile/B/B_P1.mat')
plt.plot(alld['F'][0])

# %%
alld = scipy.io.loadmat('../feature_data/matfile/C/C_P1.mat')
plt.plot(alld['F'][0])

# %%
alld = scipy.io.loadmat('../mat/me/GridA_enf.mat')

# %%
alld
# Out:
# {'F': array([[ 60.00531169,  60.00543206,  60.00875872, ...,  59.96108341,
#           59.96830763,  59.96420501]]),
#  '__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Oct 20 00:51:16 2015',
#  '__version__': '1.0'}

# %%
alld['F'][0].size
# Out:
# 2040

# %%
plt.plot(alld['F'][0])

# %%
# %load load.py
from __future__ import  division
import numpy as np
import scipy as sp
# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.io
import sklearn
from sklearn import svm

# %%
 X = [[0, 0], [1, 1]]

# %%
y = [0, 1]

# %%
clf = svm.SVC()

# %%
clf.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
clf.predict([[2,2]])
# Out:
# array([1])

# %%
ls
# Out:
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py
# neural.py          test.ipynb         write_mat.pyc

# %%
cd ..
# Out:
# /Users/mac/spcup

# %%
ls
# Out:
# data/         info/         py/
# feature_data/ mat/          test.ipynb

# %%
cd py
# Out:
# /Users/mac/spcup/py

# %%
ls
# Out:
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py
# neural.py          test.ipynb         write_mat.pyc

# %%
ls
# Out:
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py
# neural.py          test.ipynb         write_mat.pyc

# %%
# %load write_mat.py
##
#   load .mat files and write the contens to a 
#   .mat file.
#    the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def init():
    inputs = []
    targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data,target_value):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                if not re.match(r'wavelet',i): 
                    feature_name.append(i)
    input  = zip( *[ data[i][0] for i in feature_name ])

    target =  [[target_value] for i in xrange(len(input))] 

    inputs.extend(input)
    targets.extend(target)

def write_to_file(filename):
    '''
        write inputs and targets to a filename .mat file
     '''
    #np.savez(filename,inputs,targets)
    scipy.io.savemat(filename, mdict = {'inputs':inputs,'targets':targets} )



def main():
    grids = ['A','B','C','D','E','F','G','H'];
    init()

    for grid in grids:
        for i in xrange(1,12):
            #filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            #.format(grid,i)
            filename = '../mat/me/features/Grid{0}.mat'\
            .format(grid)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename), ord(grid)-ord('A')
                )
    file_to_save = 'feature_data/pyfile/features.mat'
    write_to_file(file_to_save)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-44-00bdca5bbc0e> in <module>()
#      68
#      69 if __name__ == '__main__':
# ---> 70     main()
#      71
#      72
#
# <ipython-input-44-00bdca5bbc0e> in main()
#      65                 )
#      66     file_to_save = 'feature_data/pyfile/features.mat'
# ---> 67     write_to_file(file_to_save)
#      68
#      69 if __name__ == '__main__':
#
# <ipython-input-44-00bdca5bbc0e> in write_to_file(filename)
#      47      '''
#      48     #np.savez(filename,inputs,targets)
# ---> 49     scipy.io.savemat(filename, mdict = {'inputs':inputs,'targets':targets} )
#      50
#      51
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/io/matlab/mio.pyc in savemat(file_name, mdict, appendmat, format, long_field_names, do_compression, oned_as)
#     190         if appendmat and file_name[-4:] != ".mat":
#     191             file_name = file_name + ".mat"
# --> 192         file_stream = open(file_name, 'wb')
#     193     else:
#     194         if not hasattr(file_name, 'write'):
#
# IOError: [Errno 2] No such file or directory: 'feature_data/pyfile/features.mat'

# %%
ls
# Out:
# feature_data/      neural.py          test.ipynb         write_mat.pyc
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py

# %%
# %load write_mat.py
##
#   load .mat files and write the contens to a 
#   .mat file.
#    the files has two fields - 'inputs' and 'targets'  
#   'inputs' is a numpy array of tuples
#   'targets' is from 0 to 7 (for grid 'A' to 'H')

import scipy.io
import numpy as np
import os.path
import re

inputs = []
targets = []

def init():
    inputs = []
    targets = []

def loadMat(file):
    '''
     load matfile named 'file' ..
    '''
    return scipy.io.loadmat(file)

def load_local_features(data,target_value):
    ''' load local features from data '''
    feature_name = []

    # extract the local feature name
    for i in data:
        if not re.match(r'__*',i) and i!='F' :
            if not re.match(r'global*',i):
                if not re.match(r'wavelet',i): 
                    feature_name.append(i)
    input  = zip( *[ data[i][0] for i in feature_name ])

    target =  [[target_value] for i in xrange(len(input))] 

    inputs.extend(input)
    targets.extend(target)

def write_to_file(filename):
    '''
        write inputs and targets to a filename .mat file
     '''
    #np.savez(filename,inputs,targets)
    scipy.io.savemat(filename, mdict = {'inputs':inputs,'targets':targets} )



def main():
    grids = ['A','B','C','D','E','F','G','H'];
    init()

    for grid in grids:
        for i in xrange(1,12):
            #filename = '../feature_data/matfile/{0}/{0}_P{1}.mat'\
            #.format(grid,i)
            filename = '../mat/me/features/Grid{0}.mat'\
            .format(grid)
            if os.path.exists(filename):
                load_local_features(
                    loadMat(filename), ord(grid)-ord('A')
                )
    file_to_save = 'feature_data/features.mat'
    write_to_file(file_to_save)

if __name__ == '__main__':
    main()

# %%
ls
# Out:
# feature_data/      neural.py          test.ipynb         write_mat.pyc
# index.py           neural.pyc         test_write_mat.py
# load.py            pbrain.py          write_mat.py

# %%
ls feature_data/
# Out:
# features.mat

# %%
allf = scipy.io.loadmat('feature_data/features.mat')

# %%
allf
# Out:
# {'__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file Platform: posix, Created on: Tue Oct 20 13:58:50 2015',
#  '__version__': '1.0',
#  'inputs': array([[ -0.7109509 ,  -6.24545679,  -5.4403286 ,  60.02294948,
#            1.        , -13.88056216],
#         [ -0.57511224,  -6.36115672,  -5.60568865,  60.02297139,
#            1.        , -13.92614652],
#         [ -0.63179481,  -6.50407888,  -5.92923723,  60.02243203,
#            1.        , -14.52637645],
#         ...,
#         [ -1.65715016,  -4.53467648,  -2.21450199,  50.04282168,
#            1.        ,  -6.42760601],
#         [ -1.73587005,  -4.51716009,  -2.80303806,  49.98749974,
#            1.        ,  -8.04276505],
#         [ -1.38298702,  -4.94758398,  -3.09736442,  49.92780845,
#            1.        ,  -8.69964734]]),
#  'targets': array([[0],
#         [0],
#         [0],
#         ...,
#         [7],
#         [7],
#         [7]])}

# %%
inputs = allf['inputs']

# %%
inputs
# Out:
# array([[ -0.7109509 ,  -6.24545679,  -5.4403286 ,  60.02294948,
#           1.        , -13.88056216],
#        [ -0.57511224,  -6.36115672,  -5.60568865,  60.02297139,
#           1.        , -13.92614652],
#        [ -0.63179481,  -6.50407888,  -5.92923723,  60.02243203,
#           1.        , -14.52637645],
#        ...,
#        [ -1.65715016,  -4.53467648,  -2.21450199,  50.04282168,
#           1.        ,  -6.42760601],
#        [ -1.73587005,  -4.51716009,  -2.80303806,  49.98749974,
#           1.        ,  -8.04276505],
#        [ -1.38298702,  -4.94758398,  -3.09736442,  49.92780845,
#           1.        ,  -8.69964734]])

# %%
inputs.size
# Out:
# 84942

# %%
inputs[0]
# Out:
# array([ -0.7109509 ,  -6.24545679,  -5.4403286 ,  60.02294948,
#          1.        , -13.88056216])

# %%
inputs[3]
# Out:
# array([ -0.56912445,  -6.01627349,  -4.96277957,  60.02186172,
#          1.        , -12.84384854])

# %%
targets = allf['targets']

# %%
targets
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [7],
#        [7],
#        [7]])

# %%
int(targets[2])
# Out:
# 0

# %%
last = 0
for i in xrange(len(targets)):
    if targets[i][0]>1:
        last = i-1
        break

# %%
last
# Out:
# 3574

# %%
z = zip( inputs[:last],targets[:last] )

# %%
z[0][1]
# Out:
# array([0])

# %%
import random

# %%
random.shuffle(z)

# %%
z[0][1]
# Out:
# array([1])

# %%
len(z)
# Out:
# 3574

# %%
k = int(len(z)*.75)

# %%
k
# Out:
# 2680

# %%
X = np.array([ z[i][0] for i in xrange(k) ])
print len(X)
#z[101]
Y = np.array([ int(z[i][1]) for i in xrange(k)])
print len(Y)
# Out:
# 2680
# 2680

# %%
z[3][0]
# Out:
# array([ -0.36467813,  -6.24773424,  -5.58379131,  60.02267524,
#          1.        , -14.10809178])

# %%
test = z[k:]

# %%
len(test)
# Out:
# 894

# %%
clf = svm.SVC()

# %%
clf.fit(X,Y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
len(train)
# Out:
# 2680

# %%
train[0][1]
# Out:
# array([1])

# %%
test_x = np.array([ test[i][0] for i in xrange(len(test))  ])
test_y = np.array([ int(test[i][1]) for i in xrange(len(test))  ])

# %%
len(test_y)
# Out:
# 894

# %%
p = clf.predict(test_x)

# %%
len(p)
# Out:
# 894

# %%
s = abs(p-test_y)
