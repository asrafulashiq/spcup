# %%
# %load load.py
from __future__ import  division
import numpy as np
import scipy as sp
# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.io
import sklearn
from sklearn import svm
import mpld3
mpld3.enable_notebook()

# %%
import scipy.io

# %%
a = scipy.io.loadmat("feature_n/normal_features.mat")

# %%
inputs = a['inputs']
plt.plot([k[2] for k in inputs])

# %%
inputs
# Out:
# array([[-0.03176003, -0.14893582,  0.14919547, ..., -0.04238965,
#         -0.04464848, -0.03285974],
#        [-0.03275779, -0.18515295, -0.07796386, ..., -0.05545607,
#         -0.03470128, -0.026983  ],
#        [-0.0306115 , -0.60609687, -0.09294978, ..., -0.05390325,
#         -0.04472863, -0.03428816],
#        ...,
#        [-0.03289952, -0.4665484 , -0.0676142 , ..., -0.03720275,
#         -0.03646896, -0.0276288 ],
#        [-0.03299814, -0.19517901, -0.10129433, ..., -0.04278374,
#         -0.0366445 , -0.03000617],
#        [-0.03070754, -0.05275215, -0.56184646, ..., -0.04799767,
#         -0.03130473, -0.02940215]])

# %%
b = scipy.io.loadmat('feature_n/features.mat')

# %%
inn = b['inputs']

# %%
plt.plot([k[i]] for k in inputs )
