# %%
# %load load.py
from __future__ import  division
import numpy as np
import scipy as sp
import sklearn
from matplotlib import  pyplot as plt
# %matplotlib inline
import mpld3
mpld3.enable_notebook()
import scipy.io
import os

# %%
# %load mysvm_test.py

## helper library
## standard library
from __future__ import  division
import numpy as np
import scipy as sp
import scipy.io
import os


from sklearn import preprocessing,cross_validation,svm,grid_search
from sklearn.grid_search import GridSearchCV

### get inputs and targets

filename = 'features.mat'
allf = scipy.io.loadmat(filename)
inputs = allf['inputs']
targets = allf['targets'][0]

### preprocessing

#inputs_scaled = preprocessing.scale(inputs)

### cross validation

kftotal = cross_validation.KFold(
        len(inputs),n_folds = 10, shuffle=False
    )

#clf =  svm.SVC(kernel='rbf',C=10,gamma=2)
#print cross_validation.cross_val_score( clf,inputs,targets, cv = kftotal, n_jobs = 1 )*100


### rbf

#C_range = np.logspace(-2, 10, 13)
#gamma_range = np.logspace(-9, 3, 13)
#param_grid = dict(gamma=gamma_range, C=C_range)

#grid = GridSearchCV(svm.SVC(), param_grid=param_grid, cv=kftotal)

for train,test in kftotal:
    X_train = inputs[train]
    y_train = targets[train]
    X_test = inputs[test]
    y_test = targets[test]
#X_train, X_test, y_train, y_test = cross_validation.train_test_split(inputs,targets,test_size=0.4,random_state=0)

#scaler = preprocessing.StandardScaler().fit(X_train)
#X_train_transformed = scaler.transform(X_train)

#X_test_transformed = scaler.transform(X_test)

    clf = svm.SVC(kernel='rbf',C=10,gamma=2).fit(X_train,y_train)

    pr = clf.predict(X_test)
    tar = y_test        
    for i in xrange(9):
        index = tar==i
        m = np.sum(tar==i)
        n = np.sum(pr[index]==i)
        print '######'
        print chr(i+ord('A'))," : "
        print "total :",m
        print "matched :",n
        print "efficiency :",round(n*1./m*100,2),"%"

        print "details :"    
    #for j in xrange(9):
    #    tmp = np.sum(pr[index]==j)
    #    print chr(j+ord('A'))," - ",tmp,"  ",round(tmp/m*100.0,2),"%"  

    print 

    print clf.score(X_test,y_test)*100
# Out:
# ######
# A  :
# total : 328
# matched : 149
# efficiency : 45.43 %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 45.4268292683
# ######
# A  :
# total : 6
# matched : 6
# efficiency : 100.0 %
# details :
# ######
# B  :
# total : 322
# matched : 139
# efficiency : 43.17 %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 44.2073170732
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 30
# matched : 30
# efficiency : 100.0 %
# details :
# ######
# C  :
# total : 298
# matched : 51
# efficiency : 17.11 %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 24.6951219512
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 85
# matched : 74
# efficiency : 87.06 %
# details :
# ######
# D  :
# total : 243
# matched : 204
# efficiency : 83.95 %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 84.756097561
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 145
# matched : 145
# efficiency : 100.0 %
# details :
# ######
# E  :
# total : 183
# matched : 95
# efficiency : 51.91 %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 73.1707317073
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 191
# matched : 119
# efficiency : 62.3 %
# details :
# ######
# F  :
# total : 137
# matched : 52
# efficiency : 37.96 %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 52.1341463415
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 146
# matched : 100
# efficiency : 68.49 %
# details :
# ######
# G  :
# total : 181
# matched : 87
# efficiency : 48.07 %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 57.1865443425
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 208
# matched : 95
# efficiency : 45.67 %
# details :
# ######
# H  :
# total : 119
# matched : 110
# efficiency : 92.44 %
# details :
# ######
# I  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
#
# 62.6911314985
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 261
# matched : 114
# efficiency : 43.68 %
# details :
# ######
# I  :
# total : 66
# matched : 38
# efficiency : 57.58 %
# details :
#
# 46.4831804281
# ######
# A  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# B  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# C  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# D  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# E  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# F  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# G  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# H  :
# total : 0
# matched : 0
# efficiency : nan %
# details :
# ######
# I  :
# total : 327
# matched : 165
# efficiency : 50.46 %
# details :
#
# 50.4587155963
# /Users/mac/miniconda/lib/python2.7/site-packages/ipykernel/__main__.py:68: RuntimeWarning: invalid value encountered in double_scalars

# %%
for train,test in kftotal:
    print train
# Out:
# [ 328  329  330 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 3273 3274 3275]
# [   0    1    2 ..., 2946 2947 2948]

# %%
inputs[train]
# Out:
# array([[  2.84215737e-03,  -1.59358846e+00,   5.93588473e-01, ...,
#           1.71720395e-05,   5.08385815e-06,  -2.40035234e-05],
#        [  6.48291442e-03,  -1.59358846e+00,   5.93588473e-01, ...,
#          -1.74668818e-06,   8.25203274e-06,  -1.19362630e-05],
#        [  3.49387766e-03,  -1.59358846e+00,   5.93588473e-01, ...,
#           2.33560703e-05,   4.01378674e-05,  -1.75069093e-05],
#        ...,
#        [  6.92884416e-03,  -1.22723628e+00,   2.27236265e-01, ...,
#           1.94742733e-05,   4.90733922e-05,   2.33213565e-05],
#        [  2.88673447e-03,  -1.22723628e+00,   2.27236265e-01, ...,
#          -2.82894332e-05,  -1.37423556e-05,  -3.13477786e-07],
#        [  3.08454320e-03,  -1.22723628e+00,   2.27236265e-01, ...,
#          -2.89891071e-05,  -2.26289689e-05,  -2.23667064e-05]])

# %%
y_train
# Out:
# array([2, 4, 1, ..., 4, 7, 7])
